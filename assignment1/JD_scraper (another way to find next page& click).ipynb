# %%
from selenium import webdriver
import time
# from selenium.common.exceptions import NoSuchElementException

def scrap_each_phone_info():
    all_phones = browser.find_elements_by_css_selector("li.gl-item")
    phone_info = []
    failed = []
    for phone in all_phones:
        info = {} 
        try:
            info['name'] = phone.find_element_by_class_name("p-name-type-2").find_element_by_tag_name("a").find_element_by_tag_name("em").text
            info['price'] = phone.find_element_by_class_name("p-price").find_element_by_tag_name("i").text
            info['comment'] = phone.find_element_by_class_name("p-commit").find_elements_by_tag_name("a")[-1].text
            info['shop'] = phone.find_element_by_class_name("p-shop").find_element_by_tag_name("a").text
            other_info = phone.find_element_by_class_name("p-icons").find_elements_by_tag_name("i")
            coupon = []
            for i in other_info:
                coupon.append(i.text)
            info['coupon'] = coupon
            phone_info.append(info)
            
        except NoSuchElementException as exception:
                print("Element not found")
                failed.append(info['name'])
                
    return phone_info

# %%
url = "https://www.jd.com/index.html"
browser = webdriver.Chrome()
# browser.wait = WebDriverWait(browser, 5)
browser.get(url)
keywords = browser.find_element_by_id("key").send_keys("手机\n")

# %%
data = []
for i in range(0,5):
    time.sleep(3) 
    data.extend(scrap_each_phone_info())
    element = browser.find_element_by_class_name("pn-next")
    loc = element.location
    browser.execute_script("window.scrollTo({x}, {y});".format(**loc))
    time.sleep(1)
    element = browser.find_element_by_class_name("pn-next")
    loc = element.location
    browser.execute_script("window.scrollTo({x}, {y});".format(**loc))
    time.sleep(1)
    element.click()
# Out:
# Element not found
# Element not found
# Element not found
# Element not found
# Element not found
# Element not found
# Element not found
# Element not found

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#     comment                  coupon  \
# 0      83万+        [自营, 每满1299-100]
# 1      60万+                    [自营]
# 2      41万+                    [自营]
# 3      97万+                    [自营]
# 4      73万+                    [自营]
# 5       5万+                 [自营, 赠]
# 6      44万+       [自营, 券800-100, 赠]
# 7     102万+                    [自营]
# 8      11万+                 [自营, 赠]
# 9      27万+                 [自营, 赠]
# 10     57万+                    [自营]
# 11     14万+                    [自营]
# 12    145万+                    [自营]
# 13     16万+                    [自营]
# 14    6.4万+                [自营, 新品]
# 15    115万+        [自营, 每满1099-100]
# 16     37万+         [自营, 券1280-120]
# 17    6.8万+                 [自营, 赠]
# 18     39万+             [自营, 新品, 赠]
# 19     82万+                    [自营]
# 20    3.6万+                 [自营, 赠]
# 21    8.1万+  [自营, 新品, 券2490-300, 赠]
# 22     37万+                    [自营]
# 23    7.5万+                [自营, 新品]
# 24     67万+                    [自营]
# 25     38万+                    [自营]
# 26    4.2万+             [自营, 新品, 赠]
# 27     27万+                    [自营]
# 28     13万+                [自营, 新品]
# 29    5.4万+                [自营, 新品]
# ..      ...                     ...
# 112   2400+             [满288-8, 赠]
# 113    900+              [免邮, 赠, 险]
# 114   1200+           [京东物流, 免邮, 险]
# 115    700+    [京东物流, 新品, 免邮, 赠, 险]
# 116    300+             [新品, 免邮, 赠]
# 117       0                 [自营, 赠]
# 118   1.3万+                [自营, 秒杀]
# 119    800+    [京东物流, 新品, 闪购, 赠, 险]
# 120   3800+    [京东物流, 闪购, 免邮, 赠, 险]
# 121   1000+                  [赠, 险]
# 122    500+              [免邮, 赠, 险]
# 123   6200+                      []
# 124   4800+           [京东物流, 免邮, 赠]
# 125   6.2万+                    [自营]
# 126     90+              [免邮, 赠, 险]
# 127   1800+      [免邮, 满3388-200, 赠]
# 128       0                    [自营]
# 129   1.1万+                 [免邮, 赠]
# 130   3.8万+                    [自营]
# 131   3800+    [京东物流, 闪购, 免邮, 赠, 险]
# 132   7400+                 [免邮, 赠]
# 133   1.2万+        [京东物流, 免邮, 赠, 险]
# 134   1.6万+               [京东物流, 赠]
# 135   4200+                 [免邮, 险]
# 136   3200+                    [自营]
# 137    100+      [新品, 闪购, 免邮, 赠, 险]
# 138   2.8万+              [免邮, 赠, 险]
# 139    200+         [新品, 闪购, 免邮, 赠]
# 140    500+             [新品, 免邮, 赠]
# 141    700+              [免邮, 赠, 险]
#
#                                                   name     price  \
# 0                 荣耀9i 4GB+64GB 幻夜黑 移动联通电信4G全面屏手机 双卡双待   1299.00
# 1                 小米8 全面屏游戏智能手机 6GB+64GB 黑色 全网通4G 双卡双待   2499.00
# 2             一加手机6 8GB+128GB 亮瓷黑 全面屏双摄游戏手机 全网通4G 双卡双待   3199.00
# 3          Apple iPhone X (A1865) 64GB 深空灰色 移动联通电信4G手机   6999.00
# 4    荣耀10 GT游戏加速 AIS手持夜景 6GB+64GB 幻影蓝全网通 移动联通电信4G 双...   2299.00
# 5    OPPO Find X曲面全景屏 波尔多红 8GB+128GB 全网通 移动联通电信全网通4...   4999.00
# 6    华为 HUAWEI P20 AI智慧徕卡双摄全面屏游戏手机 6GB+64GB 极光色 全网通...   3388.00
# 7                 Apple iPhone 8 64GB 红色特别版 移动联通电信4G手机   4599.00
# 8                 黑鲨游戏手机 8GB+128GB 极夜黑 液冷更快 全网通4G 双卡双待   3199.00
# 9    华为 HUAWEI P20 Pro 全面屏徕卡三摄游戏手机 6GB+128GB 极光色 全网...   4988.00
# 10     小米6X 全网通 4GB+32GB 流沙金 移动联通电信4G手机 双卡双待 智能手机 拍照手机   1149.00
# 11   华为 HUAWEI nova 3全面屏高清四摄游戏手机 6GB+128GB 亮黑色 全网通移...   2799.00
# 12           Apple iPhone 8 Plus 64GB 红色特别版 移动联通电信4G手机   5599.00
# 13       诺基亚 NOKIA X6 6GB+64GB 星空黑 全网通 双卡双待 移动联通电信4G手机   1499.00
# 14      荣耀Note10 全网通6G+64G 幻夜黑 移动联通电信4G全面屏手机 双卡双待 游戏手机   2699.00
# 15                 荣耀 畅玩7X 4GB+32GB 全网通4G全面屏手机 标配版 铂光金   1099.00
# 16   vivo Z1极光特别版 新一代全面屏AI双摄手机 6GB+64GB 移动联通电信全网通4G...   1598.00
# 17    OPPO A5 全面屏拍照手机 4GB+64GB 幻镜粉 全网通 移动联通电信4G 双卡双待手机   1499.00
# 18   荣耀8X 千元屏霸 91%屏占比 2000万AI双摄 4GB+64GB 幻夜黑 移动联通电信...   1399.00
# 19        荣耀 V10 高配版 6GB+64GB 幻夜黑 移动联通电信4G全面屏游戏手机 双卡双待   2099.00
# 20   【OPPO全新系列】K1 OPPO首款千元屏幕指纹手机 6G+64G 梵星蓝 全网通 移动联...   1799.00
# 21   vivo NEX星迹版 零界全面屏AI双摄游戏手机 8GB+128GB 移动联通电信全网通4...   4298.00
# 22                    小米 红米6 4GB+64GB 流沙金 全网通4G手机 双卡双待    829.00
# 23   小米8青春版 镜面渐变AI双摄 6GB+64GB 梦幻蓝 全网通4G 双卡双待 全面屏拍照游戏智能   1699.00
# 24    荣耀畅玩7C 全面屏手机 全网通标配版 3GB+32GB 铂光金 移动联通电信4G手机 双卡双待    799.00
# 25              小米 红米6A AI美颜 3GB+32GB 流沙金 全网通4G手机 双卡双待    599.00
# 26   vivo X23 8GB+128GB 幻夜蓝 水滴屏全面屏 游戏手机 移动联通电信全网通4G...   3498.00
# 27      小米 红米6 Pro 全网通版 4GB内存 曜石黑 32GB 移动联通电信4G手机 双卡双待    899.00
# 28   Apple iPhone XS Max (A2104) 256GB 金色 移动联通电信4G手...  10999.00
# 29     Apple iPhone XR (A2108) 64GB 白色 移动联通电信4G手机 双卡双待   6499.00
# ..                                                 ...       ...
# 112  朵唯（DOOV） V11 移动联通双4G智能手机超薄老人4G手机 学生女性大屏大字超薄老年智...    288.00
# 113             Apple 苹果 iphone XS MAX 手机 深空灰 全网通 256G  10168.00
# 114                   小米（MI） 红米6A 全面屏手机 全网通（2G+16G）铂银灰    533.00
# 115  OPPO 【3期免息】K1手机 千元首款屏幕指纹 水滴屏A5 A1 a7x升级版 r17同款...   1799.00
# 116                  Apple 苹果 iPhone XR 手机 黑色 全网通128G版   6588.00
# 117  OPPO R17 Pro 全面屏拍照手机 6GB+128GB 凝光绿 全网通移动联通电信4G...   3999.00
# 118        天语（K-TOUCH）Q31C 电信2G 直板按键 三防老人手机 学生备用功能机 黑色    138.00
# 119        OPPO 【3期免息！双色可选】 K1 首款屏下指纹水滴屏手机 4G+64G版 梵星蓝   1599.00
# 120             华为（HUAWEI） 华为nova3 手机 蓝楹紫 全网通(6G+128G)   2799.00
# 121  OPPO K1手机 【购机送智能手环】 骁龙660 R15 R17 A7x同款 A5 A3升...   1599.00
# 122     魅族（MEIZU） 魅族 16th Plus 全面屏 全网通4G手机 静夜黑 8G+128G   3498.00
# 123     vivo Y75s 全面屏 美颜拍照手机 移动联通电信4G手机 双卡双待 4+64G 磨砂黑   1598.00
# 124             华为（HUAWEI） 畅享8 Plus 手机9 金色 全网通（4G+64G）   1228.00
# 125        天语（K-TOUCH）E2 电信2G 直板按键老人手机 超长待机学生备用 老年机 金色    145.00
# 126   魅族（MEIZU） 魅族 X8 全面屏游戏手机 全网通4G手机 双卡双待 亮黑（6G+128G）   2018.00
# 127        华为（HUAWEI） P20 手机 极光色 全网通 6GB+64G【送1年原装碎屏险】   3388.00
# 128  荣耀Magic2 麒麟980AI智能芯片 超广角AI三摄 8GB+128GB 渐变黑 移动联...   4299.00
# 129                  小米（MI） mix2s 全网通手机 黑色 全网通 6G+128G   2999.00
# 130   天语（K-TOUCH）Q21 移动/联通2G 直板按键 双卡双待 老人手机 学生备用功能机 金色     59.00
# 131  【超值套装】OPPO R17享6期免息幻色渐变手机指纹解锁大屏全网通8G/6G+128G R...   3499.00
# 132             华为（HUAWEI） 荣耀v10 手机 幻夜黑 尊享版（6GB+128GB）   2399.00
# 133        华为（HUAWEI） 荣耀 畅玩6 全网通4G智能手机 双卡双待 白色（2G+16G）    538.00
# 134   vivo X21 新一代全面屏 双摄拍照手机 移动联通电信4G 双卡双待 6G+128G 冰钻黑   2798.00
# 135                       小米（MI） 红米6a 全面屏手机 流沙金 2G+16G    549.00
# 136  酷派（Coolpad） 酷玩7C 4GB+64GB全面屏 钻石黑 双曲面炫彩玻璃 移动联通电...    749.00
# 137        华为（HUAWEI） 华为Mate20 Pro 手机 亮黑色 全网通(6G+128G)   5498.00
# 138          Apple 苹果 iPhone 6s Plus 4G手机 玫瑰金 全网通 32GB   2758.00
# 139       华为（HUAWEI） 华为mate20 pro 手机 极光色 全网通 6GB+128GB   5499.00
# 140          魅族（MEIZU） 魅族 16th Plus 游戏全面屏手机 静夜黑8G+128G   3458.00
# 141          魅族（MEIZU） 魅族16th Plus 游戏手机 静夜黑 全网通6G+128G   3559.00
#
#               shop
# 0        荣耀京东自营旗舰店
# 1        小米京东自营旗舰店
# 2    一加手机京东自营官方旗舰店
# 3     京东Apple产品专营店
# 4        荣耀京东自营旗舰店
# 5    OPPO京东自营官方旗舰店
# 6      华为京东自营官方旗舰店
# 7     京东Apple产品专营店
# 8      黑鲨京东自营官方旗舰店
# 9      华为京东自营官方旗舰店
# 10       小米京东自营旗舰店
# 11     华为京东自营官方旗舰店
# 12    京东Apple产品专营店
# 13    诺基亚手机京东自营旗舰店
# 14       荣耀京东自营旗舰店
# 15       荣耀京东自营旗舰店
# 16   vivo京东自营官方旗舰店
# 17   OPPO京东自营官方旗舰店
# 18       荣耀京东自营旗舰店
# 19       荣耀京东自营旗舰店
# 20   OPPO京东自营官方旗舰店
# 21   vivo京东自营官方旗舰店
# 22       小米京东自营旗舰店
# 23       小米京东自营旗舰店
# 24       荣耀京东自营旗舰店
# 25       小米京东自营旗舰店
# 26   vivo京东自营官方旗舰店
# 27       小米京东自营旗舰店
# 28    京东Apple产品专营店
# 29    京东Apple产品专营店
# ..             ...
# 112       智慧源手机专营店
# 113        易道手机专营店
# 114        明日手机专营店
# 115    OPPO手机乐良专卖店
# 116      聚捷联盛手机旗舰店
# 117  OPPO京东自营官方旗舰店
# 118  天语手机京东自营官方旗舰店
# 119    OPPO官方直营旗舰店
# 120        炜东电商旗舰店
# 121      OPPO优品专卖店
# 122      OKSJ手机旗舰店
# 123      vivo官方旗舰店
# 124      聚捷联盛手机旗舰店
# 125  天语手机京东自营官方旗舰店
# 126      OKSJ手机旗舰店
# 127      福气多多通信专营店
# 128      荣耀京东自营旗舰店
# 129      鹏路网络手机旗舰店
# 130  天语手机京东自营官方旗舰店
# 131    OPPO酷炫手机专卖店
# 132      鹏路网络手机旗舰店
# 133      OKSJ手机旗舰店
# 134      vivo官方旗舰店
# 135        泰业手机专营店
# 136      酷派京东自营旗舰店
# 137       掌视界数码旗舰店
# 138        佳沪手机旗舰店
# 139      福气多多通信专营店
# 140      聚捷联盛手机旗舰店
# 141       掌视界数码旗舰店
#
# [142 rows x 5 columns]
